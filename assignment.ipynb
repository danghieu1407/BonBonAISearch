# %% [markdown]
# # Pre-requisites
# - WSL
# - Miniconda3

# %% [markdown]
# # Setup environment
# - Create conda env `conda create langchain python=3.11`
# - Set the "langchain" env that has been just created as the running env in VS code

# %% [markdown]
# Install langchain and openai package

# %%
! pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (1.1.1)

# %%
! pip install langchain openai
# Out:
# Requirement already satisfied: langchain in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (0.3.26)
# Requirement already satisfied: openai in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (1.93.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain) (0.3.67)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: colorama in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %% [markdown]
# # Init variables

# %% [markdown]
# You need to set value of `OPENAI_API_KEY` that you get from the training team in the .env file

# %%
import os
import openai
from dotenv import load_dotenv

load_dotenv()
openai.api_type = "azure"
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_base = os.getenv("OPENAI_API_BASE")
openai.api_version = os.getenv("OPENAI_API_VERSION")

# %% [markdown]
# # Overviews
# The BonBon FAQ.pdf file contains frequently asked questions and answers for customer support scenario. The topics are around IT related issue troubleshooting such as networking, software, hardware. You are requested to provide a solution to build a chat bot capable of answering the user questions with LangChain.

# %% [markdown]
# ## Assignment 1: Document Indexing (mandatory)

# %% [markdown]
# - The content of BonBon FAQ.pdf should be indexed to the local Chroma vector DB from where the chatbot can lookup the appropriate information to answer questions.
# - Should use some embedding model such as Azure Open AI text-embedding-ada-002 to create vectors, feel free to use any other open source embedding model if it works.

# %%
! pip install chromadb tiktoken pypdf duckduckgo-search chromadb
! pip install -U langchain-community
! pip install -U langchain-openai
! pip install -U langchain-chroma
! pip install -U langchain-core
! pip install scikit-learn
# Out:
# Requirement already satisfied: chromadb in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (1.0.13)
# Requirement already satisfied: tiktoken in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (0.9.0)
# Requirement already satisfied: pypdf in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (5.7.0)
# Requirement already satisfied: duckduckgo-search in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (8.0.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (2.3.1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (6.0.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: click>=8.1.8 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from duckduckgo-search) (8.2.1)
# Requirement already satisfied: primp>=0.15.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from duckduckgo-search) (6.0.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.1)
# Requirement already satisfied: filelock in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: langchain-community in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (0.3.67)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (0.4.4)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-community) (2.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langchain-community) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: langchain-openai in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-openai) (0.3.67)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-openai) (1.93.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai) (0.4.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai) (4.14.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-openai) (3.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai) (3.10)
# Requirement already satisfied: certifi in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# Requirement already satisfied: colorama in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.86.0->langchain-openai) (0.4.6)
# Requirement already satisfied: langchain-chroma in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (0.2.4)
# Requirement already satisfied: langchain-core>=0.3.60 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-chroma) (0.3.67)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-chroma) (2.3.1)
# Requirement already satisfied: chromadb>=1.0.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-chroma) (1.0.13)
# Requirement already satisfied: build>=1.0.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (2.11.7)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.35.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (6.0.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (4.24.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (0.4.6)
# Requirement already satisfied: anyio in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.32.4)
# Requirement already satisfied: requests-oauthlib in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.6.1)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core>=0.3.60->langchain-chroma) (0.4.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core>=0.3.60->langchain-chroma) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.3.60->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.3.60->langchain-chroma) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.3.60->langchain-chroma) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.9->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.9->langchain-chroma) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.9->langchain-chroma) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (3.4.2)
# Requirement already satisfied: coloredlogs in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (5.29.5)
# Requirement already satisfied: sympy in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.9->langchain-chroma) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from posthog>=2.4.0->chromadb>=1.0.9->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from posthog>=2.4.0->chromadb>=1.0.9->langchain-chroma) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (0.33.1)
# Requirement already satisfied: filelock in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (2025.5.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from anyio->httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.3.0)
# Requirement already satisfied: langchain-core in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (0.3.67)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core) (0.4.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core) (4.14.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langchain-core) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from langsmith>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=2.7.4->langchain-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from pydantic>=2.7.4->langchain-core) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: scikit-learn in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hi\.conda\envs\langchain-training\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from langchain.document_loaders import PyPDFLoader
from langchain_openai import AzureOpenAIEmbeddings
from langchain.vectorstores import Chroma
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

def initialize_faq_vectorstore(pdf_path: str = "data/BonBon FAQ.pdf", persist_dir: str = "chroma_db") -> Chroma:
    pdf_loader = PyPDFLoader(pdf_path)
    faq_documents = pdf_loader.load()

    embedding_model = AzureOpenAIEmbeddings(
        deployment=os.getenv("OPENAI_API_DELOYMENT_NAME"),
        model=os.getenv("OPENAI_API_MODEL_NAME"),
        openai_api_key=os.getenv("OPENAI_API_KEY"),
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        openai_api_version=os.getenv("OPENAI_API_VERSION")
    )

    vector_store = Chroma.from_documents(
        documents=faq_documents,
        embedding=embedding_model,
        persist_directory=persist_dir
    )
    return vector_store

# Initialize the vectorstore
vectordb = initialize_faq_vectorstore()
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %% [markdown]
# ## Assignment 2: Building Chatbot (mandatory)
# - You are requested to build a chatbot solution for customer support scenario using Conversational ReAct agent supported in LangChain
# - The chatbot is able to support user to answer FAQs in the sample BonBon FAQ.pdf file.
# - The chatbot should use Azure Open AI GPT-3.5 LLM as the reasoning engine.
# - The chatbot should be context aware, meaning that it should be able to chat with users in the conversation manner.
# - The agent is equipped the following tools:
#   - Internet Search: Help the chatbot automatically find out more about something using Duck Duck Go internet search
#   - Knowledge Base Search: Help the chatbot to lookup information in the private knowledge base
# - In case user asks for information related to topics in the BonBon FAQ.pdf file such as internet connection, printer, malware issues the chatbot must use the private knowledge base, otherwise it should search on the internet to answer the question.
# - In the answer of chatbot, it should mention the source file and the page that the answer belongs to, for example the answer should mention "BonBon FQA.pdf (page 2)"

# %%
import os
import sys
import time
import logging
from typing import Optional
from pathlib import Path


from dotenv import load_dotenv
from langchain.document_loaders import PyPDFLoader
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI
from langchain.chains import RetrievalQA
from langchain.tools import DuckDuckGoSearchRun
from langchain.schema.messages import HumanMessage

try:
    from langchain_chroma import Chroma
except ImportError:
    from langchain.vectorstores import Chroma


class SmartFAQBot:
    def __init__(self, pdf_file: str = "data/BonBon FAQ.pdf", db_path: str = "chroma_db", max_results: int = 3):
        self.pdf_file = Path(pdf_file)
        self.db_path = Path(db_path)
        self.max_results = max_results
        
        self.embedder: Optional[AzureOpenAIEmbeddings] = None
        self.vector_store: Optional[Chroma] = None
        self.llm: Optional[AzureChatOpenAI] = None
        self.search_tool: Optional[DuckDuckGoSearchRun] = None
        
        logging.basicConfig(level=logging.ERROR)
        self.logger = logging.getLogger(__name__)
        
        load_dotenv()
        self._init_all()
    
    def _init_all(self):
        try:
            self._init_embedder()
            self._load_pdf_data()
            self._init_chat()
            self._init_search()
        except Exception as e:
            self.logger.error(f"Bot initialization failed: {e}")
            raise
    
    def _init_embedder(self):
        self.embedder = AzureOpenAIEmbeddings(
            deployment=os.getenv("OPENAI_API_DELOYMENT_NAME"),
            model=os.getenv("OPENAI_API_MODEL_NAME"),
            openai_api_key=os.getenv("OPENAI_API_KEY"),
            azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
            openai_api_version=os.getenv("OPENAI_API_VERSION")
        )
    
    def _load_pdf_data(self):
        if not self.pdf_file.exists():
            raise FileNotFoundError(f"PDF file not found: {self.pdf_file}")
        
        if self.db_path.exists() and any(self.db_path.iterdir()):
            self.vector_store = Chroma(persist_directory=str(self.db_path), embedding_function=self.embedder)
        else:
            loader = PyPDFLoader(str(self.pdf_file))
            documents = loader.load()
            
            if not documents:
                raise ValueError("PDF contains no readable content")
            
            self.vector_store = Chroma.from_documents(
                documents=documents, embedding=self.embedder, persist_directory=str(self.db_path)
            )
            self.vector_store.persist()
    
    def _init_chat(self):
        try:
            endpoint = os.getenv("AZURE_OPENAI_CHAT_ENDPOINT") or os.getenv("AZURE_OPENAI_ENDPOINT")
            api_key = os.getenv("OPENAI_API_CHAT_KEY") or os.getenv("OPENAI_API_KEY")
            
            self.llm = AzureChatOpenAI(
                deployment_name=os.getenv("OPENAI_API_CHAT_DEPLOYMENT_NAME"),
                model_name=os.getenv("OPENAI_API_CHAT_MODEL_NAME"),
                openai_api_key=api_key,
                azure_endpoint=endpoint,
                openai_api_version=os.getenv("OPENAI_API_VERSION"),
                temperature=0.1,
                max_tokens=1000
            )
        except Exception as e:
            self.logger.error(f"Chat model setup failed: {e}")
            raise
    
    def _init_search(self):
        self.search_tool = DuckDuckGoSearchRun()
    
    def _is_faq_query(self, question: str) -> bool:
        tech_keywords = [
            "internet", "printer", "computer", "software", "hardware", "network", 
            "connection", "troubleshoot", "fix", "error", "slow", "not working", 
            "can't", "won't", "malware", "virus", "install", "setup", "configure", 
            "password", "wifi", "browser", "email", "login", "update", "crash",
            "freeze", "boot", "startup", "driver", "device", "usb", "monitor",
            "keyboard", "mouse", "sound", "audio", "video", "screen", "display"
        ]
        
        question_lower = question.lower()
        return any(keyword in question_lower for keyword in tech_keywords)
    
    def _get_faq_answer(self, question: str) -> str:
        try:
            retriever = self.vector_store.as_retriever(search_kwargs={"k": self.max_results})
            qa_chain = RetrievalQA.from_chain_type(
                llm=self.llm, retriever=retriever, return_source_documents=True, verbose=False
            )
            
            result = qa_chain.invoke({"query": question})
            answer = result["result"]
            docs = result.get("source_documents", [])
            
            page_refs = set()
            for doc in docs:
                source = doc.metadata.get("source", "BonBon FAQ.pdf")
                page_num = doc.metadata.get("page")
                if page_num is not None:
                    page_refs.add((Path(source).name, int(page_num) + 1))
            
            response = f"\n\n**Answer:**\n{answer.strip()}"
            
            if page_refs:
                sources = "\n".join([f"- {file} (Page {page})" for file, page in sorted(page_refs)])
                response += f"\n\n**Sources:**\n{sources}"
            
            return response + "\n" + "-" * 50
            
        except Exception as e:
            return f"\n\n**FAQ Error:**\nCould not retrieve answer: {str(e)}\n" + "-" * 50
    
    def _web_search(self, question: str) -> str:
        try:
            time.sleep(1)
            result = self.search_tool.run(question)
            return f"\n\n**Web Search:**\n{result.strip()}\n" + "-" * 50
        except Exception:
            return (f"\n\n**Search Unavailable:**\n"
                   f"Web search is currently unavailable. Please try again later or "
                   f"ask about topics in our FAQ database.\n" + "-" * 50)
    
    def get_response(self, question: str) -> str:
        if not question.strip():
            return "Please ask a valid question."
        
        try:
            if self._is_faq_query(question):
                return self._get_faq_answer(question)
            else:
                return self._web_search(question)
        except Exception as e:
            return f"**Error:** An unexpected error occurred: {str(e)}"
    
    def start_chat(self):
        print("Smart FAQ Bot is ready!")
        print("Ask technical questions or general topics.")
        print("Commands: 'exit', 'quit', 'q' to stop.\n")
        
        while True:
            try:
                user_question = input("Your question (or 'exit'): ").strip()
                
                if user_question.lower() in ["exit", "quit", "q"]:
                    print("Goodbye!")
                    break
                
                if not user_question:
                    print("Please enter a question.\n")
                    continue
                
                response = self.get_response(user_question)
                print(response)
                print()
                
            except KeyboardInterrupt:
                print("\nBye!")
                break
            except Exception as e:
                print(f"Error: {e}\n")


def init_vector_db(pdf_file: str = "data/BonBon FAQ.pdf", db_path: str = "chroma_db") -> Chroma:
    try:
        bot = SmartFAQBot(pdf_file=pdf_file, db_path=db_path)
        return bot.vector_store
    except Exception as e:
        raise


def create_faq_bot(pdf_file: str = "data/BonBon FAQ.pdf", db_path: str = "chroma_db") -> SmartFAQBot:
    return SmartFAQBot(pdf_file=pdf_file, db_path=db_path)


if __name__ == "__main__":
    try:
        bot = create_faq_bot()
        bot.start_chat()
    except Exception as e:
        print(f"Bot startup failed: {e}")
        sys.exit(1)
# Out:
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Smart FAQ Bot is ready!
# Ask technical questions or general topics.
# Commands: 'exit', 'quit', 'q' to stop.
# Your question (or 'exit'):  1 + 1  = ?
# **Web Search:**
# Trong toán học, 1 + 1 luôn bằng 2. Nhưng trong đời sống vì sao 1 + 1 lại có nhiều đáp số? Ý thức và thái độ quyết định kết quả. Đối với nhiều người, câu hỏi tưởng như vô cùng đơn giản: "Tại sao 1 + 1 = 2?" lại là một trong những câu hỏi khó trả lời nhất. Tại sao? Vì nó gần như là hiển nhiên. Bạn có 1 trái táo, sau đó có người cho bạn 1 trái nữa, thì bạn có 2 trái, tự nhiên nó đã như thế. Ever wondered why 1 + 1 always equals 2 and not 3, 4, or 5? In just one minute, we break down the fundamental principles of mathematics that make this equation a universal truth. Explore the ... 1.1.1.1 with WARP replaces your connection with a more modern and optimized protocol — making things much more private compared to traditional wired protocols. Available on both PC and mobile, this anti-spy software makes sure that your data is always safe each time you go online. What is 1 + 1 in Boolean Algebra? A Beginner's Guide Boolean algebra, a fascinating branch of mathematics, forms the bedrock of digital logic and computer science. Unlike traditional arithmetic, where 1 + 1 = 2, Boolean algebra operates with only two values: 0 (false) and 1 (true). Understanding how operations work within this system is crucial for anyone delving into computer science, digital ...
# --------------------------------------------------
# Your question (or 'exit'):   How do I reset my password?
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# **Answer:**
# To reset your password, you can go to the "Where to Reset my Password for which application" web page at the following link: www.anycorp.intranet.passwordreset.com. There, you will be able to select the application for which you need to reset your password and follow the provided instructions.
#
# **Sources:**
# - BonBon FAQ.pdf (Page 3)
# --------------------------------------------------

# %% [markdown]
# ## Assignment 3: Build a new assistant based on BonBon source code (optional)
# The objective
# - Run the code and index the sample BonBon FAQ.pdf file to Azure Cognitive Search
# - Explore the code and implement a new assistant that has the same behavior as above
# - Explore other features such as RBACs, features on admin portal
#
# Please contact the training team in case you need to get the source code of BonBon.
